# %% [markdown]
# # Titanic

# %%
import pandas as pd
titanic_set = pd.read_csv('titanic_train.csv')
print(titanic_set.shape)
# affiche des infos sur la dataset
print(titanic_set.columns)
titanic_set["Sex"].unique()
titanic_set.head(10)
# Out:
# (891, 12)
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# ...

# %%
mask=(titanic_set['Sex']=='123456')
titanic_set.loc[mask,'Sex']='male'

#titanic_set['Sex'].unique()

# %%
titanic_set['Embarked']
# select les colonnes de types float et integer
titanic_set.select_dtypes(include=['int64','float64']).head()
# Out:
#    PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare
# 0            1         0       3  22.0      1      0   7.2500
# 1            2         1       1  38.0      1      0  71.2833
# 2            3         1       3  26.0      0      0   7.9250
# 3            4         1       1  35.0      1      0  53.1000
# 4            5         0       3  35.0      0      0   8.0500

# %%
titanic_set.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
titanic_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %% [markdown]
# # Visualisation des données

# %%
#df_titanic.groupby('Age').count()
#print(df_titanic.describe)
titanic_set['family_size'] = titanic_set['Parch']+ titanic_set['SibSp'] +1
sns.barplot(x="family_size", y='Survived', data=titanic_set)

# %%
sns.barplot(x="family_size", y='Pclass', data=titanic_set)

# %%
import seaborn as sns
sns.barplot(x="Sex", y='Survived', data=titanic_set)

# %%
titanic_set['Age'].hist()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.barplot(x="Parch", y='Survived', data=titanic_set)

# %%
mean= int(titanic_set['Age'].sum()/len(titanic_set['Age']))
print(mean)
# remplace les columns nan par la moyenne 
titanic_set['Age'] = titanic_set['Age'].fillna(titanic_set['Age'].median())
#print(titanic_set['Age'])
# Out:
# 23

# %%
sns.barplot(x="Pclass", y='Survived', hue ='Sex',data=titanic_set)

# %%
sns.barplot(x="SibSp", y='Survived', data=titanic_set)

# %%
sns.barplot(x="Embarked", y='Survived', data=titanic_set)
#plt.title('nombre de survivants en fonction embarqemment')

# %%
# sellection des colonnes 
#sns.set_style('')
sns.barplot(x="Embarked", y='Survived', hue ='Pclass',palette = 'hls',data=titanic_set)
#sns.palplot(sns.color_palette("hls", 8))

# %%
dset =titanic_set.drop(['PassengerId','Survived','Name','Ticket','Cabin','Sex','Embarked'], axis =1)
# remplace toutes les valeurs nan par la mediane des données 
dset = dset.fillna(dset.median())

y_data = titanic_set['Survived']

# %%
dset.head()
dset.corr()
# Out:
#                Pclass       Age     SibSp     Parch      Fare  family_size
# Pclass       1.000000 -0.339898  0.083081  0.018443 -0.549500     0.065997
# Age         -0.339898  1.000000 -0.233296 -0.172482  0.096688    -0.245619
# SibSp        0.083081 -0.233296  1.000000  0.414838  0.159651     0.890712
# Parch        0.018443 -0.172482  0.414838  1.000000  0.216225     0.783111
# Fare        -0.549500  0.096688  0.159651  0.216225  1.000000     0.217138
# family_size  0.065997 -0.245619  0.890712  0.783111  0.217138     1.000000

# %%
dset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 6 columns):
# Pclass         891 non-null int64
# Age            891 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Fare           891 non-null float64
# family_size    891 non-null int64
# dtypes: float64(2), int64(4)
# memory usage: 41.8 KB

# %%
#titanic_set.info()

# %% [markdown]
# # ML

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import LabelEncoder

X_train, X_test, Y_train , Y_test = train_test_split(dset,y_data, test_size = 0.2 )
logic = LogisticRegression()
logic.fit(X_train,Y_train)
pred = logic.predict(X_test)
accuracy_score(Y_test, pred)
# Out:
# 0.6815642458100558

# %% [markdown]
# #  (test avec d'autres colonnes )

# %%
from sklearn.preprocessing import LabelEncoder
lbe = LabelEncoder()
# modifie la colonne sex en numerique
titanic_set['Sex_code']= lbe.fit_transform(titanic_set['Sex'])
titanic_set.loc[titanic_set['Cabin'].isna(),'Cabin']='123'
titanic_set['code_cabin']=lbe.fit_transform(titanic_set['Cabin'])
titanic_set.loc[titanic_set["Embarked"].isna(),'Embarked']='C'
titanic_set['Embarked_code'] =  lbe.fit_transform(titanic_set['Embarked'])
titanic_set.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  family_size  Sex_code  \
# 0      0         A/5 21171   7.2500   123        S            2         1
# 1      0          PC 17599  71.2833   C85        C            2         0
# 2      0  STON/O2. 3101282   7.9250   123        S            1         0
# ...

# %%
print(titanic_set['Embarked_code'].unique())
# Out:
# [2 0 1]

# %%
#MFdict={'male':0,'female':1}
#dset['Sex']=
#dset.loc[:,"Sex"].apply(lambda x : MFdict[x])
dset1 =titanic_set.drop(['Survived','Name','Ticket','Cabin','Embarked','Sex','code_cabin'], axis =1)
dset1 = dset1.fillna(dset1.median())
dset1.head()
# Out:
#    PassengerId  Pclass   Age  SibSp  Parch     Fare  family_size  Sex_code  \
# 0            1       3  22.0      1      0   7.2500            2         1
# 1            2       1  38.0      1      0  71.2833            2         0
# 2            3       3  26.0      0      0   7.9250            1         0
# 3            4       1  35.0      1      0  53.1000            2         0
# 4            5       3  35.0      0      0   8.0500            1         1
#
#    Embarked_code
# 0              2
# 1              0
# 2              2
# 3              2
# 4              2

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import LabelEncoder

X_train, X_test, Y_train , Y_test = train_test_split(dset1,y_data, test_size = 0.2 )
logic = LogisticRegression()
logic.fit(X_train,Y_train)
pred = logic.predict(X_test)
accuracy_score(Y_test, pred)
# Out:
# 0.8100558659217877

# %%
X_test
# Out:
#      PassengerId  Pclass   Age  SibSp  Parch     Fare  family_size  Sex_code  \
# 383          384       1  35.0      1      0  52.0000            2         0
# 37            38       3  21.0      0      0   8.0500            1         1
# 405          406       2  34.0      1      0  21.0000            2         1
# 817          818       2  31.0      1      1  37.0042            3         1
# 402          403       3  21.0      1      0   9.8250            2         0
# 729          730       3  25.0      1      0   7.9250            2         0
# 862          863       1  48.0      0      0  25.9292            1         0
# 754          755       2  48.0      1      2  65.0000            4         0
# 208          209       3  16.0      0      0   7.7500            1         0
# 501          502       3  21.0      0      0   7.7500            1         0
# 569          570       3  32.0      0      0   7.8542            1         1
# ...

# %% [markdown]
# # dataset test

# %%
dtest = pd.read_csv('titanic_test.csv')
male = dtest['Sex']=='123456'
dtest.loc[male,'Sex']='male'
dtest['Sex'].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder
lbe = LabelEncoder()
# modifie la colonne sex en numerique
dtest['Sex_code']= lbe.fit_transform(dtest['Sex'])
dtest.loc[dtest['Cabin'].isna(),'Cabin']='123'
dtest['code_cabin']=lbe.fit_transform(dtest['Cabin'])
dtest.loc[dtest["Embarked"].isna(),'Embarked']='N'
dtest['Embarked_code'] =  lbe.fit_transform(dtest['Embarked'])

# %%
dtest.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 14 columns):
# PassengerId      418 non-null int64
# Pclass           418 non-null int64
# Name             418 non-null object
# Sex              418 non-null object
# Age              332 non-null float64
# SibSp            418 non-null int64
# Parch            418 non-null int64
# Ticket           418 non-null object
# Fare             417 non-null float64
# Cabin            418 non-null object
# Embarked         418 non-null object
# Sex_code         418 non-null int64
# code_cabin       418 non-null int64
# Embarked_code    418 non-null int64
# dtypes: float64(2), int64(7), object(5)
# memory usage: 45.8+ KB

# %%
#dtest.drop(['Name','Ticket','Cabin','Embarked','Sex'], axis=1)

# %%
tset = dtest.drop(['Name','Ticket','Cabin','Embarked','Sex','code_cabin'], axis=1)
tset = tset.fillna(tset.median())
tset.head()
# Out:
#    PassengerId  Pclass   Age  SibSp  Parch     Fare  Sex_code  Embarked_code
# 0          892       3  34.5      0      0   7.8292         1              1
# 1          893       3  47.0      1      0   7.0000         0              2
# 2          894       2  62.0      0      0   9.6875         1              1
# 3          895       3  27.0      0      0   8.6625         1              2
# 4          896       3  22.0      1      1  12.2875         0              2

# %% [markdown]
# # preparation csv soumission

# %%
X= tset
pred = logic.predict(X)
print(pred)
#CSV creation
my_submission = pd.DataFrame({'PassengerId': tset.PassengerId, 'Survived': pred})
my_submission.to_csv('submission.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-31-df1e2610babf> in <module>()
#       1 X= tset
# ----> 2 pred = logic.predict(X)
#       3 print(pred)
#       4 #CSV creation
#       5 my_submission = pd.DataFrame({'PassengerId': tset.PassengerId, 'Survived': pred})
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\base.py in predict(self, X)
#     322             Predicted class label per sample.
#     323         """
# --> 324         scores = self.decision_function(X)
#     325         if len(scores.shape) == 1:
#     326             indices = (scores > 0).astype(np.int)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\base.py in decision_function(self, X)
#     303         if X.shape[1] != n_features:
#     304             raise ValueError("X has %d features per sample; expecting %d"
# ...

# %%
accuracy_score(Y_test, pred)
